# %% [markdown]
# Dataset : [Wine Dataset](https://archive.ics.uci.edu/ml/datasets/wine)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("wine.data", header=None)
df.columns = [
 'class',
 'alcohol',
 'malic_acid',
 'ash',
 'alcalinity_of_ash',
 'magnesium',
 'total_phenols',
 'flavanoids',
 'nonflavanoid_phenols',
 'proanthocyanins',
 'color_intensity',
 'hue',
 'od280/od315',
 'proline']
df
# Out:
#      class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df2 = df.copy()
df2['class_color'] = ''
for i,r in df2.iterrows():
    c = r['class'] 
    if c == 1:
        df2.at[i, 'class_color'] = 'green'
    elif c == 2:
        df2.at[i, 'class_color'] = 'yellow'
    elif c == 3:
        df2.at[i, 'class_color'] = 'blue'
        
df2
# Out:
#      class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
def plot_graph(axs, x_col, y_col):
    data = {
        x_col: df2[x_col],
        y_col: df2[y_col],
        'class_color': df2['class_color']
    }
    axs.set_title(x_col + ' vs ' + y_col)
    axs.set_xlabel(x_col)
    axs.set_ylabel(y_col)
    axs.scatter(x_col, y_col, c='class_color', data=data)
    
cols = ['malic_acid',
 'ash',
 'alcalinity_of_ash',
 'magnesium',
 'total_phenols',
 'flavanoids',
 'nonflavanoid_phenols',
 'proanthocyanins',
 'color_intensity',
 'hue',
 'od280/od315',
 'proline']

fig, axs = plt.subplots(4, 3, figsize=(20, 20))
i=0
j=0
for col in cols:
    plot_graph(axs[i][j], 'alcohol', col)
    j+=1
    if j > 2:
        j = 0
        i+=1

# %%
sns.heatmap(df.corr(), cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                          class   alcohol  malic_acid       ash  \
# class                 1.000000 -0.328222    0.437776 -0.049643
# alcohol              -0.328222  1.000000    0.094397  0.211545
# malic_acid            0.437776  0.094397    1.000000  0.164045
# ash                  -0.049643  0.211545    0.164045  1.000000
# alcalinity_of_ash     0.517859 -0.310235    0.288500  0.443367
# magnesium            -0.209179  0.270798   -0.054575  0.286587
# total_phenols        -0.719163  0.289101   -0.335167  0.128980
# flavanoids           -0.847498  0.236815   -0.411007  0.115077
# nonflavanoid_phenols  0.489109 -0.155929    0.292977  0.186230
# proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# color_intensity       0.265668  0.546364    0.248985  0.258887
# hue                  -0.617369 -0.071747   -0.561296 -0.074667
# od280/od315          -0.788230  0.072343   -0.368710  0.003911
# proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
'''
test_count = 10 # test record count
tci = test_count * -1 # test index cut off
TRAIN = pd.concat([df[df['class'] == 1][:tci], df[df['class'] == 2][:tci], df[df['class'] == 3][:tci]])
TEST =  pd.concat([df[df['class'] == 1][tci:], df[df['class'] == 2][tci:], df[df['class'] == 3][tci:]])
TRAIN
'''
# Out:
# "\ntest_count = 10 # test record count\ntci = test_count * -1 # test index cut off\nTRAIN = pd.concat([df[df['class'] == 1][:tci], df[df['class'] == 2][:tci], df[df['class'] == 3][:tci]])\nTEST =  pd.concat([df[df['class'] == 1][tci:], df[df['class'] == 2][tci:], df[df['class'] == 3][tci:]])\nTRAIN\n"

# %%
'''
x_train = TRAIN.loc[:, TRAIN.columns != 'class']
y_train = TRAIN.loc[:, TRAIN.columns == 'class']
x_test = TEST.loc[:, TEST.columns != 'class']
y_test = TEST.loc[:, TEST.columns == 'class']
'''
# Out:
# "\nx_train = TRAIN.loc[:, TRAIN.columns != 'class']\ny_train = TRAIN.loc[:, TRAIN.columns == 'class']\nx_test = TEST.loc[:, TEST.columns != 'class']\ny_test = TEST.loc[:, TEST.columns == 'class']\n"

# %%
X=df.drop(['class'],axis=1)
y=df['class']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X)
xscaled=scaler.transform(X)
X_scaled=pd.DataFrame(xscaled,columns=df.columns[1:])
X_scaled.head()
# Out:
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1  0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2  0.196879    0.021231  1.109334          -0.268738   0.088358
# 3  1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4  0.295700    0.227694  1.840403           0.451946   1.281985
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0       0.808997    1.034819             -0.659563         1.224884
# 1       0.568648    0.733629             -0.820719        -0.544721
# 2       0.808997    1.215533             -0.498407         2.135968
# 3       2.491446    1.466525             -0.981875         1.032155
# 4       0.808997    0.663351              0.226796         0.401404
#
#    color_intensity       hue  od280/od315   proline
# 0         0.251717  0.362177     1.847920  1.013009
# 1        -0.293321  0.406051     1.113449  0.965242
# ...

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3, random_state=23)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score


knn=KNeighborsClassifier(n_neighbors=23)
cv_scores = cross_val_score(knn, X, y, cv=10)
print(cv_scores)
print('cv_scores mean:{}'.format(np.mean(cv_scores)))
# Out:
# [0.72222222 0.83333333 0.72222222 0.66666667 0.61111111 0.66666667
#  0.77777778 0.72222222 0.76470588 0.82352941]
# cv_scores mean:0.7310457516339869

# %%
from sklearn.model_selection import GridSearchCV
#create new a knn model
knn2 = KNeighborsClassifier()
#create a dictionary of all values we want to test for n_neighbors
param_grid = {'n_neighbors': np.arange(3, 25)}
#use gridsearch to test all values for n_neighbors
knn_gscv = GridSearchCV(knn2, param_grid, cv=10)
#fit model to data
knn_gscv.fit(X, y)
knn_gscv.best_params_
# Out:
# {'n_neighbors': 23}
